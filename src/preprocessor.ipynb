# %%
import os, re, json

# %%
source_path = "../data/raw"
target_path = "../data/processed"

# %%
# Fetch payer list from file
with open(os.path.join(source_path, "payer_list.json"), "r") as f:
    payer_list = json.loads(f.read())

# %%
payer_list
# Out:
# [{'name': 'United Healthcare', 'abbr': 'UHC'},
#  {'name': 'Elevance Health', 'abbr': 'ANTM'},
#  {'name': 'Aetna', 'abbr': 'AET'},
#  {'name': 'Cigna Healthcare', 'abbr': 'CI'},
#  {'name': 'Humana', 'abbr': 'HUM'},
#  {'name': 'Kaiser Permanente', 'abbr': 'KP'},
#  {'name': 'Centene Corporation', 'abbr': 'CNC'},
#  {'name': 'Molina Healthcare', 'abbr': 'MOH'},
#  {'name': 'Blue Cross Blue Shield Association', 'abbr': 'BCBSA'},
#  {'name': 'Health Care Service Corporation', 'abbr': 'HCSC'},
#  {'name': 'Highmark Health', 'abbr': 'HMI'},
#  {'name': 'Geisinger Health Plan', 'abbr': 'GHP'},
#  {'name': 'UPMC Health Plan', 'abbr': 'UPMC'},
#  {'name': 'Independence Blue Cross', 'abbr': 'IBC'},
#  {'name': 'Harvard Pilgrim Health Care', 'abbr': 'HPHC'},
#  {'name': 'Tufts Health Plan', 'abbr': 'THP'},
#  {'name': 'WellCare Health Plans', 'abbr': 'WCG'},
#  {'name': 'Tricare', 'abbr': 'TRI'},
#  {'name': 'Medicare', 'abbr': 'MCR'},
#  {'name': 'Medicaid', 'abbr': 'MCD'}]

# %%
# Get list of relevant files for preprocessing
dd_files = []
ddl_files = []

for f in os.listdir(source_path):
    if f.endswith('_ddl.sql'):
        ddl_files.append(f)
    elif f.endswith('_data_dictionary.json'):
        dd_files.append(f)

files = {"dd": dd_files, "ddl": ddl_files}

# %%
files
# Out:
# {'dd': ['mcd_eligibility_mcd_data_dictionary.json',
#   'hmi_claims_hmi_data_dictionary.json',
#   'upmc_rxclaims_upmc_data_dictionary.json',
#   'bcbsa_eligibility_bcbsa_data_dictionary.json',
#   'hphc_rxclaims_hphc_data_dictionary.json',
#   'aet_claims_aet_data_dictionary.json',
#   'uhc_rxclaims_uhc_data_dictionary.json',
#   'upmc_claims_upmc_data_dictionary.json',
#   'cnc_claims_cnc_data_dictionary.json',
#   'uhc_eligibility_uhc_data_dictionary.json',
#   'uhc_claims_uhc_data_dictionary.json',
#   'hum_eligibility_hum_data_dictionary.json',
#   'antm_claims_antm_data_dictionary.json',
#   'hmi_rxclaims_hmi_data_dictionary.json',
#   'antm_rxclaims_antm_data_dictionary.json',
#   'wcg_rxclaims_wcg_data_dictionary.json',
#   'kp_claims_kp_data_dictionary.json',
#   'ci_claims_ci_data_dictionary.json',
#   'claims_standard_claims_data_dictionary.json',
#   'upmc_eligibility_upmc_data_dictionary.json',
#   'moh_rxclaims_moh_data_dictionary.json',
#   'hphc_eligibility_hphc_data_dictionary.json',
#   'hmi_eligibility_hmi_data_dictionary.json',
#   'hcsc_claims_hcsc_data_dictionary.json',
#   'moh_eligibility_moh_data_dictionary.json',
#   'hcsc_rxclaims_hcsc_data_dictionary.json',
#   'eligibility_standard_eligibility_data_dictionary.json',
#   'antm_eligibility_antm_data_dictionary.json',
#   'bcbsa_claims_bcbsa_data_dictionary.json',
#   'bcbsa_rxclaims_bcbsa_data_dictionary.json',
#   'mcr_claims_mcr_data_dictionary.json',
#   'moh_claims_moh_data_dictionary.json',
#   'cnc_eligibility_cnc_data_dictionary.json',
#   'aet_eligibility_aet_data_dictionary.json',
#   'rxclaims_standard_rxclaims_data_dictionary.json',
#   'ghp_eligibility_ghp_data_dictionary.json',
#   'thp_claims_thp_data_dictionary.json',
#   'kp_rxclaims_kp_data_dictionary.json',
#   'wcg_eligibility_wcg_data_dictionary.json',
#   'ibc_claims_ibc_data_dictionary.json',
#   'aet_rxclaims_aet_data_dictionary.json',
#   'tri_eligibility_tri_data_dictionary.json',
#   'mcd_claims_mcd_data_dictionary.json',
#   'tri_rxclaims_tri_data_dictionary.json',
#   'wcg_claims_wcg_data_dictionary.json',
#   'mcr_eligibility_mcr_data_dictionary.json',
#   'ghp_claims_ghp_data_dictionary.json',
#   'kp_eligibility_kp_data_dictionary.json',
#   'hphc_claims_hphc_data_dictionary.json',
#   'ci_rxclaims_ci_data_dictionary.json',
#   'thp_rxclaims_thp_data_dictionary.json',
#   'mcd_rxclaims_mcd_data_dictionary.json',
#   'mcr_rxclaims_mcr_data_dictionary.json',
#   'hum_rxclaims_hum_data_dictionary.json',
#   'hcsc_eligibility_hcsc_data_dictionary.json',
#   'thp_eligibility_thp_data_dictionary.json',
#   'cnc_rxclaims_cnc_data_dictionary.json',
#   'ghp_rxclaims_ghp_data_dictionary.json',
#   'ibc_rxclaims_ibc_data_dictionary.json',
#   'ibc_eligibility_ibc_data_dictionary.json',
#   'tri_claims_tri_data_dictionary.json',
#   'hum_claims_hum_data_dictionary.json',
#   'ci_eligibility_ci_data_dictionary.json'],
#  'ddl': ['source_layouts_eligibility_ddl.sql',
#   'source_layouts_claims_ddl.sql',
#   'source_layouts_rxclaims_ddl.sql',
#   'standard_layouts_ddl.sql']}

# %%
def write_to_file(data: list[dict], file_name: str):
    """Write data to given file name."""
    with open(file_name, "w") as fw:
        json.dump(data, fw, indent=2)
    print(f"File written successfully to: {file_name}")

def get_payer_name_abbr(table_name: str) -> dict:
    """Returns payer name and abbreviation for given table name."""
    abbr = table_name.split("_")[-1]
    for payer in payer_list:
        if abbr.upper() == payer["abbr"]:
            return payer.values()
    else:
        return {"name": "Default", "abbr": "default"}.values()

def format_ddl(file_name: str) -> list[dict]:
    """Returns preprocessed list of dictionaries of DDLs."""
    with open(os.path.join(source_path, file_name), 'r') as f:
        content = f.read()
    
    ddl_scripts = [stmt.strip() + ';' for stmt in content.split(';') if stmt.strip()]
    result = []
    for ddl in ddl_scripts:
        match = re.search(r'CREATE\s+TABLE\s+([^\s(]+)', ddl, re.IGNORECASE)
        table_name = match.group(1) if match else None
        client_name, client_abbr = get_payer_name_abbr(table_name)
        metadata = {
            "file_name": file_name,
            "file_path": source_path,
            "table_name": table_name,
            "client_name": client_name,
            "client_abbr": client_abbr
        }
        result.append({"content": ddl, "metadata": metadata})
    return result

def format_dd(file_name: str) -> list[dict]:
    """Returns preprocessed list of dictionaries of data dictionary."""
    with open(os.path.join(source_path, file_name), 'r') as f:
        content = json.load(f)
    
    result = []
    for item in content:
        dd = '\n'.join(f"{k}: {v}" for k, v in item.items())
        table_name = "_".join(file_name.split("data_dictionary")[0].split("_")[1:3])
        client_name, client_abbr = get_payer_name_abbr(table_name)
        metadata = {
            "file_name": file_name,
            "file_path": source_path,
            "table_name": table_name,
            "client_name": client_name,
            "client_abbr": client_abbr
        }
        result.append({"content": dd, "metadata": metadata})
    return result

# %%
# Prepare DDLs
processed_ddls = []
for ddl_file in files["ddl"]:
    processed_ddls.extend(format_ddl(ddl_file))
    print(f"Processed File: {ddl_file}")
# Out:
# Processed File: source_layouts_eligibility_ddl.sql
# Processed File: source_layouts_claims_ddl.sql
# Processed File: source_layouts_rxclaims_ddl.sql
# Processed File: standard_layouts_ddl.sql

# %%
processed_ddls
# Out:
# [{'content': 'CREATE TABLE eligibility_uhc (\n    sub_member_id VARCHAR2(50),\n    first_name_code VARCHAR2(35),\n    mem_last_name VARCHAR2(60),\n    sub_date_of_birth_val DATE,\n    mem_gender_val CHAR(1),\n    address_id VARCHAR2(100),\n    city_code VARCHAR2(30),\n    state_nm CHAR(2),\n    sub_zip_code_id VARCHAR2(9),\n    sub_plan_id_code VARCHAR2(30),\n    mem_group_number_code VARCHAR2(50),\n    coverage_start_date_val DATE,\n    coverage_end_date_id DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'CREATE TABLE eligibility_antm (\n    mem_member_id_nm VARCHAR2(50),\n    first_name_code VARCHAR2(35),\n    last_name_nm VARCHAR2(60),\n    date_of_birth DATE,\n    sub_gender_val CHAR(1),\n    address_val VARCHAR2(100),\n    city VARCHAR2(30),\n    state_nm CHAR(2),\n    zip_code_code VARCHAR2(9),\n    plan_id_code VARCHAR2(30),\n    group_number_val VARCHAR2(50),\n    coverage_start_date_val DATE,\n    mem_coverage_end_date_val DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_antm',
#    'client_name': 'Elevance Health',
#    'client_abbr': 'ANTM'}},
#  {'content': 'CREATE TABLE eligibility_aet (\n    mem_member_id_nm VARCHAR2(50),\n    first_name_id VARCHAR2(35),\n    last_name VARCHAR2(60),\n    sub_date_of_birth_code DATE,\n    gender_val CHAR(1),\n    mem_address VARCHAR2(100),\n    city VARCHAR2(30),\n    mem_state_val CHAR(2),\n    zip_code_id VARCHAR2(9),\n    plan_id_nm VARCHAR2(30),\n    mem_group_number_code VARCHAR2(50),\n    sub_coverage_start_date_nm DATE,\n    coverage_end_date_nm DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'CREATE TABLE eligibility_ci (\n    member_id_val VARCHAR2(50),\n    mem_first_name_val VARCHAR2(35),\n    last_name_code VARCHAR2(60),\n    date_of_birth DATE,\n    gender_id CHAR(1),\n    address VARCHAR2(100),\n    city_val VARCHAR2(30),\n    state_val CHAR(2),\n    mem_zip_code_code VARCHAR2(9),\n    plan_id_val VARCHAR2(30),\n    mem_group_number VARCHAR2(50),\n    mem_coverage_start_date_val DATE,\n    coverage_end_date_nm DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'CREATE TABLE eligibility_hum (\n    mem_member_id_id VARCHAR2(50),\n    first_name_id VARCHAR2(35),\n    mem_last_name_val VARCHAR2(60),\n    date_of_birth DATE,\n    gender_code CHAR(1),\n    sub_address_nm VARCHAR2(100),\n    sub_city_nm VARCHAR2(30),\n    sub_state CHAR(2),\n    mem_zip_code VARCHAR2(9),\n    plan_id VARCHAR2(30),\n    group_number VARCHAR2(50),\n    mem_coverage_start_date_val DATE,\n    sub_coverage_end_date_id DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'CREATE TABLE eligibility_kp (\n    mem_member_id VARCHAR2(50),\n    mem_first_name_nm VARCHAR2(35),\n    last_name_code VARCHAR2(60),\n    mem_date_of_birth_code DATE,\n    sub_gender_code CHAR(1),\n    mem_address_id VARCHAR2(100),\n    sub_city_id VARCHAR2(30),\n    state_code CHAR(2),\n    mem_zip_code_id VARCHAR2(9),\n    plan_id_nm VARCHAR2(30),\n    group_number_code VARCHAR2(50),\n    sub_coverage_start_date_nm DATE,\n    sub_coverage_end_date_code DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_kp',
#    'client_name': 'Kaiser Permanente',
#    'client_abbr': 'KP'}},
#  {'content': 'CREATE TABLE eligibility_cnc (\n    member_id_nm VARCHAR2(50),\n    first_name_val VARCHAR2(35),\n    sub_last_name_val VARCHAR2(60),\n    date_of_birth_code DATE,\n    gender CHAR(1),\n    address_val VARCHAR2(100),\n    mem_city_nm VARCHAR2(30),\n    state_val CHAR(2),\n    zip_code_id VARCHAR2(9),\n    plan_id VARCHAR2(30),\n    group_number_id VARCHAR2(50),\n    coverage_start_date DATE,\n    coverage_end_date_code DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'CREATE TABLE eligibility_moh (\n    member_id VARCHAR2(50),\n    mem_first_name_nm VARCHAR2(35),\n    mem_last_name VARCHAR2(60),\n    mem_date_of_birth_val DATE,\n    gender_id CHAR(1),\n    address_nm VARCHAR2(100),\n    mem_city_id VARCHAR2(30),\n    state_nm CHAR(2),\n    sub_zip_code_id VARCHAR2(9),\n    plan_id VARCHAR2(30),\n    group_number VARCHAR2(50),\n    sub_coverage_start_date DATE,\n    sub_coverage_end_date_nm DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_moh',
#    'client_name': 'Molina Healthcare',
#    'client_abbr': 'MOH'}},
#  {'content': 'CREATE TABLE eligibility_bcbsa (\n    sub_member_id_nm VARCHAR2(50),\n    first_name_nm VARCHAR2(35),\n    last_name_nm VARCHAR2(60),\n    date_of_birth_nm DATE,\n    gender CHAR(1),\n    address VARCHAR2(100),\n    mem_city_id VARCHAR2(30),\n    state_code CHAR(2),\n    zip_code VARCHAR2(9),\n    mem_plan_id VARCHAR2(30),\n    group_number_code VARCHAR2(50),\n    mem_coverage_start_date_code DATE,\n    sub_coverage_end_date DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'CREATE TABLE eligibility_hcsc (\n    sub_member_id_id VARCHAR2(50),\n    sub_first_name_code VARCHAR2(35),\n    last_name_id VARCHAR2(60),\n    date_of_birth DATE,\n    mem_gender_code CHAR(1),\n    address_nm VARCHAR2(100),\n    city VARCHAR2(30),\n    sub_state_val CHAR(2),\n    mem_zip_code_id VARCHAR2(9),\n    sub_plan_id_code VARCHAR2(30),\n    sub_group_number_nm VARCHAR2(50),\n    mem_coverage_start_date DATE,\n    coverage_end_date_id DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hcsc',
#    'client_name': 'Health Care Service Corporation',
#    'client_abbr': 'HCSC'}},
#  {'content': 'CREATE TABLE eligibility_hmi (\n    mem_member_id_val VARCHAR2(50),\n    mem_first_name_val VARCHAR2(35),\n    last_name_id VARCHAR2(60),\n    sub_date_of_birth_id DATE,\n    sub_gender_val CHAR(1),\n    mem_address VARCHAR2(100),\n    city_val VARCHAR2(30),\n    state CHAR(2),\n    zip_code_nm VARCHAR2(9),\n    plan_id_code VARCHAR2(30),\n    group_number_code VARCHAR2(50),\n    coverage_start_date_nm DATE,\n    coverage_end_date_code DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'CREATE TABLE eligibility_ghp (\n    mem_member_id_id VARCHAR2(50),\n    first_name_code VARCHAR2(35),\n    last_name_code VARCHAR2(60),\n    mem_date_of_birth_id DATE,\n    mem_gender_nm CHAR(1),\n    sub_address_id VARCHAR2(100),\n    sub_city VARCHAR2(30),\n    sub_state_id CHAR(2),\n    zip_code_code VARCHAR2(9),\n    plan_id VARCHAR2(30),\n    group_number_code VARCHAR2(50),\n    coverage_start_date DATE,\n    coverage_end_date DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ghp',
#    'client_name': 'Geisinger Health Plan',
#    'client_abbr': 'GHP'}},
#  {'content': 'CREATE TABLE eligibility_upmc (\n    mem_member_id_code VARCHAR2(50),\n    mem_first_name_code VARCHAR2(35),\n    last_name_val VARCHAR2(60),\n    date_of_birth DATE,\n    mem_gender_id CHAR(1),\n    mem_address VARCHAR2(100),\n    city VARCHAR2(30),\n    sub_state_id CHAR(2),\n    zip_code_nm VARCHAR2(9),\n    plan_id_code VARCHAR2(30),\n    group_number VARCHAR2(50),\n    coverage_start_date_id DATE,\n    mem_coverage_end_date_nm DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'CREATE TABLE eligibility_ibc (\n    sub_member_id_id VARCHAR2(50),\n    first_name_nm VARCHAR2(35),\n    last_name VARCHAR2(60),\n    date_of_birth DATE,\n    sub_gender_nm CHAR(1),\n    address_val VARCHAR2(100),\n    city_code VARCHAR2(30),\n    state_val CHAR(2),\n    zip_code_id VARCHAR2(9),\n    mem_plan_id_val VARCHAR2(30),\n    mem_group_number VARCHAR2(50),\n    mem_coverage_start_date_nm DATE,\n    mem_coverage_end_date_code DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'CREATE TABLE eligibility_hphc (\n    member_id_val VARCHAR2(50),\n    sub_first_name_val VARCHAR2(35),\n    last_name VARCHAR2(60),\n    mem_date_of_birth DATE,\n    gender_val CHAR(1),\n    address_code VARCHAR2(100),\n    sub_city_nm VARCHAR2(30),\n    state_nm CHAR(2),\n    mem_zip_code VARCHAR2(9),\n    mem_plan_id VARCHAR2(30),\n    group_number_nm VARCHAR2(50),\n    coverage_start_date_nm DATE,\n    mem_coverage_end_date DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'CREATE TABLE eligibility_thp (\n    member_id_val VARCHAR2(50),\n    first_name_val VARCHAR2(35),\n    mem_last_name_nm VARCHAR2(60),\n    mem_date_of_birth_code DATE,\n    sub_gender_val CHAR(1),\n    mem_address_nm VARCHAR2(100),\n    sub_city_id VARCHAR2(30),\n    state_val CHAR(2),\n    zip_code VARCHAR2(9),\n    mem_plan_id_id VARCHAR2(30),\n    sub_group_number_id VARCHAR2(50),\n    coverage_start_date_id DATE,\n    coverage_end_date_id DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_thp',
#    'client_name': 'Tufts Health Plan',
#    'client_abbr': 'THP'}},
#  {'content': 'CREATE TABLE eligibility_wcg (\n    member_id_id VARCHAR2(50),\n    sub_first_name_code VARCHAR2(35),\n    last_name_id VARCHAR2(60),\n    date_of_birth_nm DATE,\n    mem_gender CHAR(1),\n    address VARCHAR2(100),\n    city VARCHAR2(30),\n    sub_state CHAR(2),\n    zip_code VARCHAR2(9),\n    mem_plan_id_code VARCHAR2(30),\n    group_number VARCHAR2(50),\n    coverage_start_date_val DATE,\n    sub_coverage_end_date_val DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_wcg',
#    'client_name': 'WellCare Health Plans',
#    'client_abbr': 'WCG'}},
#  {'content': 'CREATE TABLE eligibility_tri (\n    mem_member_id_nm VARCHAR2(50),\n    mem_first_name VARCHAR2(35),\n    last_name_code VARCHAR2(60),\n    mem_date_of_birth DATE,\n    gender_nm CHAR(1),\n    address_val VARCHAR2(100),\n    mem_city VARCHAR2(30),\n    state_nm CHAR(2),\n    mem_zip_code_val VARCHAR2(9),\n    plan_id_nm VARCHAR2(30),\n    group_number_code VARCHAR2(50),\n    coverage_start_date_val DATE,\n    sub_coverage_end_date_code DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'CREATE TABLE eligibility_mcr (\n    sub_member_id_nm VARCHAR2(50),\n    mem_first_name_nm VARCHAR2(35),\n    last_name_val VARCHAR2(60),\n    date_of_birth_nm DATE,\n    sub_gender_val CHAR(1),\n    address_id VARCHAR2(100),\n    mem_city_nm VARCHAR2(30),\n    state_val CHAR(2),\n    sub_zip_code_val VARCHAR2(9),\n    mem_plan_id_id VARCHAR2(30),\n    group_number_code VARCHAR2(50),\n    sub_coverage_start_date_val DATE,\n    coverage_end_date_val DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcr',
#    'client_name': 'Medicare',
#    'client_abbr': 'MCR'}},
#  {'content': 'CREATE TABLE eligibility_mcd (\n    sub_member_id_code VARCHAR2(50),\n    first_name VARCHAR2(35),\n    mem_last_name_code VARCHAR2(60),\n    date_of_birth_nm DATE,\n    sub_gender CHAR(1),\n    address_val VARCHAR2(100),\n    city_code VARCHAR2(30),\n    state_val CHAR(2),\n    sub_zip_code_id VARCHAR2(9),\n    sub_plan_id_val VARCHAR2(30),\n    mem_group_number_val VARCHAR2(50),\n    mem_coverage_start_date DATE,\n    sub_coverage_end_date_code DATE\n);',
#   'metadata': {'file_name': 'source_layouts_eligibility_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'CREATE TABLE claims_uhc (\n    drg_claim_id_id VARCHAR2(35),\n    mem_member_id_id VARCHAR2(50),\n    sub_service_date_code DATE,\n    phm_admission_date_nm DATE,\n    mem_discharge_date_val DATE,\n    mem_procedure_code_val VARCHAR2(10),\n    diagnosis_code VARCHAR2(10),\n    clm_billed_amount_nm NUMBER(10, 2),\n    drg_paid_amount NUMBER(10, 2),\n    sub_provider_id_val VARCHAR2(35),\n    phm_claim_status_code VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'CREATE TABLE claims_antm (\n    rx_claim_id_id VARCHAR2(35),\n    clm_member_id_val VARCHAR2(50),\n    mem_service_date DATE,\n    phm_admission_date_code DATE,\n    drg_discharge_date_val DATE,\n    procedure_code_id VARCHAR2(10),\n    diagnosis_code_nm VARCHAR2(10),\n    billed_amount_nm NUMBER(10, 2),\n    clm_paid_amount_nm NUMBER(10, 2),\n    sub_provider_id_val VARCHAR2(35),\n    drg_claim_status_nm VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_antm',
#    'client_name': 'Elevance Health',
#    'client_abbr': 'ANTM'}},
#  {'content': 'CREATE TABLE claims_aet (\n    clm_claim_id_id VARCHAR2(35),\n    member_id_code VARCHAR2(50),\n    clm_service_date DATE,\n    mem_admission_date DATE,\n    drg_discharge_date_id DATE,\n    mem_procedure_code_val VARCHAR2(10),\n    clm_diagnosis_code_id VARCHAR2(10),\n    rx_billed_amount_val NUMBER(10, 2),\n    paid_amount_val NUMBER(10, 2),\n    provider_id_val VARCHAR2(35),\n    rx_claim_status_id VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'CREATE TABLE claims_ci (\n    mem_claim_id VARCHAR2(35),\n    member_id_val VARCHAR2(50),\n    sub_service_date_id DATE,\n    drg_admission_date_code DATE,\n    clm_discharge_date_id DATE,\n    phm_procedure_code_nm VARCHAR2(10),\n    phm_diagnosis_code_nm VARCHAR2(10),\n    mem_billed_amount_id NUMBER(10, 2),\n    clm_paid_amount_code NUMBER(10, 2),\n    sub_provider_id_val VARCHAR2(35),\n    rx_claim_status_code VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'CREATE TABLE claims_hum (\n    mem_claim_id_id VARCHAR2(35),\n    rx_member_id_id VARCHAR2(50),\n    rx_service_date DATE,\n    phm_admission_date DATE,\n    discharge_date_val DATE,\n    phm_procedure_code_val VARCHAR2(10),\n    phm_diagnosis_code VARCHAR2(10),\n    drg_billed_amount_id NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    rx_provider_id_code VARCHAR2(35),\n    clm_claim_status VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'CREATE TABLE claims_kp (\n    clm_claim_id VARCHAR2(35),\n    mem_member_id_val VARCHAR2(50),\n    sub_service_date DATE,\n    phm_admission_date DATE,\n    phm_discharge_date DATE,\n    rx_procedure_code_nm VARCHAR2(10),\n    diagnosis_code_nm VARCHAR2(10),\n    mem_billed_amount_val NUMBER(10, 2),\n    rx_paid_amount_code NUMBER(10, 2),\n    drg_provider_id_code VARCHAR2(35),\n    sub_claim_status_id VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_kp',
#    'client_name': 'Kaiser Permanente',
#    'client_abbr': 'KP'}},
#  {'content': 'CREATE TABLE claims_cnc (\n    sub_claim_id_val VARCHAR2(35),\n    rx_member_id_id VARCHAR2(50),\n    service_date_nm DATE,\n    clm_admission_date_id DATE,\n    phm_discharge_date_val DATE,\n    rx_procedure_code_id VARCHAR2(10),\n    rx_diagnosis_code_val VARCHAR2(10),\n    sub_billed_amount_id NUMBER(10, 2),\n    sub_paid_amount_val NUMBER(10, 2),\n    phm_provider_id VARCHAR2(35),\n    claim_status_id VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'CREATE TABLE claims_moh (\n    claim_id_nm VARCHAR2(35),\n    clm_member_id_val VARCHAR2(50),\n    drg_service_date_val DATE,\n    sub_admission_date DATE,\n    discharge_date_val DATE,\n    phm_procedure_code_code VARCHAR2(10),\n    rx_diagnosis_code VARCHAR2(10),\n    clm_billed_amount_nm NUMBER(10, 2),\n    rx_paid_amount NUMBER(10, 2),\n    mem_provider_id VARCHAR2(35),\n    rx_claim_status_val VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_moh',
#    'client_name': 'Molina Healthcare',
#    'client_abbr': 'MOH'}},
#  {'content': 'CREATE TABLE claims_bcbsa (\n    sub_claim_id VARCHAR2(35),\n    mem_member_id_nm VARCHAR2(50),\n    clm_service_date_val DATE,\n    mem_admission_date DATE,\n    drg_discharge_date_nm DATE,\n    clm_procedure_code_val VARCHAR2(10),\n    clm_diagnosis_code_nm VARCHAR2(10),\n    phm_billed_amount_val NUMBER(10, 2),\n    phm_paid_amount_val NUMBER(10, 2),\n    sub_provider_id_code VARCHAR2(35),\n    phm_claim_status_code VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'CREATE TABLE claims_hcsc (\n    drg_claim_id_nm VARCHAR2(35),\n    rx_member_id VARCHAR2(50),\n    sub_service_date_val DATE,\n    rx_admission_date_val DATE,\n    sub_discharge_date_code DATE,\n    clm_procedure_code_code VARCHAR2(10),\n    sub_diagnosis_code VARCHAR2(10),\n    sub_billed_amount_code NUMBER(10, 2),\n    paid_amount_nm NUMBER(10, 2),\n    drg_provider_id_code VARCHAR2(35),\n    rx_claim_status VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hcsc',
#    'client_name': 'Health Care Service Corporation',
#    'client_abbr': 'HCSC'}},
#  {'content': 'CREATE TABLE claims_hmi (\n    claim_id_val VARCHAR2(35),\n    clm_member_id_nm VARCHAR2(50),\n    sub_service_date_val DATE,\n    mem_admission_date_nm DATE,\n    clm_discharge_date_val DATE,\n    clm_procedure_code_val VARCHAR2(10),\n    sub_diagnosis_code_id VARCHAR2(10),\n    billed_amount NUMBER(10, 2),\n    sub_paid_amount_code NUMBER(10, 2),\n    sub_provider_id_code VARCHAR2(35),\n    claim_status_val VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'CREATE TABLE claims_ghp (\n    sub_claim_id_val VARCHAR2(35),\n    sub_member_id_nm VARCHAR2(50),\n    rx_service_date_id DATE,\n    drg_admission_date DATE,\n    sub_discharge_date_val DATE,\n    rx_procedure_code_nm VARCHAR2(10),\n    phm_diagnosis_code VARCHAR2(10),\n    mem_billed_amount_id NUMBER(10, 2),\n    paid_amount_id NUMBER(10, 2),\n    provider_id_code VARCHAR2(35),\n    sub_claim_status_nm VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_ghp',
#    'client_name': 'Geisinger Health Plan',
#    'client_abbr': 'GHP'}},
#  {'content': 'CREATE TABLE claims_upmc (\n    mem_claim_id_nm VARCHAR2(35),\n    phm_member_id_code VARCHAR2(50),\n    phm_service_date_nm DATE,\n    phm_admission_date_val DATE,\n    drg_discharge_date_nm DATE,\n    mem_procedure_code VARCHAR2(10),\n    drg_diagnosis_code_id VARCHAR2(10),\n    mem_billed_amount NUMBER(10, 2),\n    rx_paid_amount_val NUMBER(10, 2),\n    mem_provider_id_val VARCHAR2(35),\n    drg_claim_status VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'CREATE TABLE claims_ibc (\n    sub_claim_id_code VARCHAR2(35),\n    member_id_code VARCHAR2(50),\n    rx_service_date DATE,\n    phm_admission_date_id DATE,\n    mem_discharge_date_code DATE,\n    procedure_code_id VARCHAR2(10),\n    mem_diagnosis_code_val VARCHAR2(10),\n    drg_billed_amount_id NUMBER(10, 2),\n    paid_amount_nm NUMBER(10, 2),\n    sub_provider_id_val VARCHAR2(35),\n    phm_claim_status_code VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'CREATE TABLE claims_hphc (\n    sub_claim_id_val VARCHAR2(35),\n    phm_member_id VARCHAR2(50),\n    mem_service_date_nm DATE,\n    admission_date DATE,\n    clm_discharge_date DATE,\n    procedure_code VARCHAR2(10),\n    diagnosis_code_id VARCHAR2(10),\n    drg_billed_amount_val NUMBER(10, 2),\n    paid_amount_id NUMBER(10, 2),\n    provider_id_code VARCHAR2(35),\n    rx_claim_status_nm VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'CREATE TABLE claims_thp (\n    drg_claim_id_id VARCHAR2(35),\n    phm_member_id_code VARCHAR2(50),\n    service_date_nm DATE,\n    rx_admission_date_nm DATE,\n    discharge_date_id DATE,\n    phm_procedure_code_val VARCHAR2(10),\n    mem_diagnosis_code_nm VARCHAR2(10),\n    billed_amount_nm NUMBER(10, 2),\n    paid_amount_val NUMBER(10, 2),\n    mem_provider_id_nm VARCHAR2(35),\n    drg_claim_status_id VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_thp',
#    'client_name': 'Tufts Health Plan',
#    'client_abbr': 'THP'}},
#  {'content': 'CREATE TABLE claims_wcg (\n    mem_claim_id VARCHAR2(35),\n    phm_member_id_code VARCHAR2(50),\n    rx_service_date_code DATE,\n    phm_admission_date_val DATE,\n    drg_discharge_date DATE,\n    phm_procedure_code VARCHAR2(10),\n    phm_diagnosis_code_code VARCHAR2(10),\n    rx_billed_amount NUMBER(10, 2),\n    rx_paid_amount_val NUMBER(10, 2),\n    rx_provider_id VARCHAR2(35),\n    claim_status_val VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_wcg',
#    'client_name': 'WellCare Health Plans',
#    'client_abbr': 'WCG'}},
#  {'content': 'CREATE TABLE claims_tri (\n    clm_claim_id_id VARCHAR2(35),\n    drg_member_id_val VARCHAR2(50),\n    phm_service_date_val DATE,\n    admission_date_code DATE,\n    clm_discharge_date DATE,\n    rx_procedure_code_id VARCHAR2(10),\n    mem_diagnosis_code_code VARCHAR2(10),\n    billed_amount NUMBER(10, 2),\n    mem_paid_amount NUMBER(10, 2),\n    mem_provider_id VARCHAR2(35),\n    sub_claim_status_code VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'CREATE TABLE claims_mcr (\n    phm_claim_id_code VARCHAR2(35),\n    rx_member_id_nm VARCHAR2(50),\n    drg_service_date_val DATE,\n    sub_admission_date DATE,\n    rx_discharge_date_nm DATE,\n    clm_procedure_code_nm VARCHAR2(10),\n    rx_diagnosis_code_nm VARCHAR2(10),\n    sub_billed_amount_id NUMBER(10, 2),\n    sub_paid_amount_id NUMBER(10, 2),\n    sub_provider_id VARCHAR2(35),\n    rx_claim_status_val VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_mcr',
#    'client_name': 'Medicare',
#    'client_abbr': 'MCR'}},
#  {'content': 'CREATE TABLE claims_mcd (\n    sub_claim_id_nm VARCHAR2(35),\n    sub_member_id_code VARCHAR2(50),\n    phm_service_date_nm DATE,\n    sub_admission_date_val DATE,\n    phm_discharge_date_id DATE,\n    procedure_code_id VARCHAR2(10),\n    rx_diagnosis_code_code VARCHAR2(10),\n    rx_billed_amount NUMBER(10, 2),\n    mem_paid_amount_code NUMBER(10, 2),\n    mem_provider_id VARCHAR2(35),\n    clm_claim_status VARCHAR2(20)\n);',
#   'metadata': {'file_name': 'source_layouts_claims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'claims_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'CREATE TABLE rxclaims_uhc (\n    rx_claim_id VARCHAR2(35),\n    sub_member_id_val VARCHAR2(50),\n    rx_pharmacy_id_code VARCHAR2(35),\n    sub_fill_date DATE,\n    rx_drug_code_id VARCHAR2(15),\n    drg_quantity_dispensed_nm NUMBER(10, 2),\n    rx_days_supply_code NUMBER(3),\n    rx_billed_amount_code NUMBER(10, 2),\n    clm_paid_amount NUMBER(10, 2),\n    phm_prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'CREATE TABLE rxclaims_antm (\n    sub_rx_claim_id VARCHAR2(35),\n    mem_member_id_id VARCHAR2(50),\n    pharmacy_id_val VARCHAR2(35),\n    clm_fill_date_val DATE,\n    clm_drug_code_code VARCHAR2(15),\n    sub_quantity_dispensed_id NUMBER(10, 2),\n    clm_days_supply NUMBER(3),\n    drg_billed_amount NUMBER(10, 2),\n    phm_paid_amount_code NUMBER(10, 2),\n    sub_prescriber_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_antm',
#    'client_name': 'Elevance Health',
#    'client_abbr': 'ANTM'}},
#  {'content': 'CREATE TABLE rxclaims_aet (\n    rx_rx_claim_id_code VARCHAR2(35),\n    phm_member_id VARCHAR2(50),\n    clm_pharmacy_id_nm VARCHAR2(35),\n    rx_fill_date_id DATE,\n    drug_code VARCHAR2(15),\n    mem_quantity_dispensed_id NUMBER(10, 2),\n    mem_days_supply NUMBER(3),\n    phm_billed_amount_id NUMBER(10, 2),\n    clm_paid_amount_code NUMBER(10, 2),\n    drg_prescriber_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'CREATE TABLE rxclaims_ci (\n    rx_claim_id_nm VARCHAR2(35),\n    phm_member_id_val VARCHAR2(50),\n    sub_pharmacy_id_code VARCHAR2(35),\n    mem_fill_date_val DATE,\n    phm_drug_code VARCHAR2(15),\n    mem_quantity_dispensed_id NUMBER(10, 2),\n    clm_days_supply_id NUMBER(3),\n    rx_billed_amount_nm NUMBER(10, 2),\n    mem_paid_amount_code NUMBER(10, 2),\n    mem_prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'CREATE TABLE rxclaims_hum (\n    sub_rx_claim_id_code VARCHAR2(35),\n    rx_member_id VARCHAR2(50),\n    drg_pharmacy_id_code VARCHAR2(35),\n    phm_fill_date_nm DATE,\n    sub_drug_code_nm VARCHAR2(15),\n    rx_quantity_dispensed_nm NUMBER(10, 2),\n    mem_days_supply_val NUMBER(3),\n    billed_amount_id NUMBER(10, 2),\n    phm_paid_amount_nm NUMBER(10, 2),\n    prescriber_id_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'CREATE TABLE rxclaims_kp (\n    sub_rx_claim_id_code VARCHAR2(35),\n    mem_member_id_nm VARCHAR2(50),\n    clm_pharmacy_id_nm VARCHAR2(35),\n    rx_fill_date_val DATE,\n    drg_drug_code_code VARCHAR2(15),\n    phm_quantity_dispensed NUMBER(10, 2),\n    mem_days_supply_code NUMBER(3),\n    mem_billed_amount_val NUMBER(10, 2),\n    mem_paid_amount_val NUMBER(10, 2),\n    prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_kp',
#    'client_name': 'Kaiser Permanente',
#    'client_abbr': 'KP'}},
#  {'content': 'CREATE TABLE rxclaims_cnc (\n    rx_rx_claim_id_nm VARCHAR2(35),\n    rx_member_id_id VARCHAR2(50),\n    phm_pharmacy_id_id VARCHAR2(35),\n    drg_fill_date_id DATE,\n    drg_drug_code VARCHAR2(15),\n    sub_quantity_dispensed NUMBER(10, 2),\n    mem_days_supply_id NUMBER(3),\n    mem_billed_amount_code NUMBER(10, 2),\n    sub_paid_amount_id NUMBER(10, 2),\n    rx_prescriber_id_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'CREATE TABLE rxclaims_moh (\n    mem_rx_claim_id_val VARCHAR2(35),\n    clm_member_id_code VARCHAR2(50),\n    clm_pharmacy_id_id VARCHAR2(35),\n    rx_fill_date_val DATE,\n    drg_drug_code VARCHAR2(15),\n    mem_quantity_dispensed_code NUMBER(10, 2),\n    drg_days_supply NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    sub_paid_amount_nm NUMBER(10, 2),\n    rx_prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_moh',
#    'client_name': 'Molina Healthcare',
#    'client_abbr': 'MOH'}},
#  {'content': 'CREATE TABLE rxclaims_bcbsa (\n    rx_claim_id_id VARCHAR2(35),\n    sub_member_id VARCHAR2(50),\n    clm_pharmacy_id VARCHAR2(35),\n    fill_date_val DATE,\n    drg_drug_code_val VARCHAR2(15),\n    rx_quantity_dispensed_val NUMBER(10, 2),\n    mem_days_supply_code NUMBER(3),\n    billed_amount_nm NUMBER(10, 2),\n    rx_paid_amount_val NUMBER(10, 2),\n    drg_prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'CREATE TABLE rxclaims_hcsc (\n    drg_rx_claim_id_id VARCHAR2(35),\n    member_id_code VARCHAR2(50),\n    phm_pharmacy_id VARCHAR2(35),\n    sub_fill_date_nm DATE,\n    mem_drug_code_nm VARCHAR2(15),\n    rx_quantity_dispensed_nm NUMBER(10, 2),\n    drg_days_supply_id NUMBER(3),\n    mem_billed_amount_id NUMBER(10, 2),\n    paid_amount_val NUMBER(10, 2),\n    mem_prescriber_id_val VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hcsc',
#    'client_name': 'Health Care Service Corporation',
#    'client_abbr': 'HCSC'}},
#  {'content': 'CREATE TABLE rxclaims_hmi (\n    sub_rx_claim_id_nm VARCHAR2(35),\n    member_id_nm VARCHAR2(50),\n    drg_pharmacy_id_code VARCHAR2(35),\n    drg_fill_date_id DATE,\n    drug_code_code VARCHAR2(15),\n    sub_quantity_dispensed_val NUMBER(10, 2),\n    sub_days_supply NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    rx_prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'CREATE TABLE rxclaims_ghp (\n    clm_rx_claim_id_val VARCHAR2(35),\n    phm_member_id_id VARCHAR2(50),\n    sub_pharmacy_id VARCHAR2(35),\n    drg_fill_date DATE,\n    sub_drug_code_id VARCHAR2(15),\n    phm_quantity_dispensed_nm NUMBER(10, 2),\n    rx_days_supply NUMBER(3),\n    drg_billed_amount_code NUMBER(10, 2),\n    sub_paid_amount_nm NUMBER(10, 2),\n    drg_prescriber_id_nm VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_ghp',
#    'client_name': 'Geisinger Health Plan',
#    'client_abbr': 'GHP'}},
#  {'content': 'CREATE TABLE rxclaims_upmc (\n    drg_rx_claim_id_nm VARCHAR2(35),\n    clm_member_id VARCHAR2(50),\n    rx_pharmacy_id_id VARCHAR2(35),\n    clm_fill_date_val DATE,\n    rx_drug_code_code VARCHAR2(15),\n    mem_quantity_dispensed NUMBER(10, 2),\n    drg_days_supply_val NUMBER(3),\n    clm_billed_amount_code NUMBER(10, 2),\n    clm_paid_amount_val NUMBER(10, 2),\n    phm_prescriber_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'CREATE TABLE rxclaims_ibc (\n    drg_rx_claim_id_nm VARCHAR2(35),\n    phm_member_id_code VARCHAR2(50),\n    sub_pharmacy_id_nm VARCHAR2(35),\n    mem_fill_date_id DATE,\n    phm_drug_code_code VARCHAR2(15),\n    mem_quantity_dispensed_code NUMBER(10, 2),\n    drg_days_supply_id NUMBER(3),\n    billed_amount_id NUMBER(10, 2),\n    mem_paid_amount_nm NUMBER(10, 2),\n    rx_prescriber_id_code VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'CREATE TABLE rxclaims_hphc (\n    clm_rx_claim_id_val VARCHAR2(35),\n    sub_member_id_val VARCHAR2(50),\n    drg_pharmacy_id_nm VARCHAR2(35),\n    rx_fill_date_nm DATE,\n    drg_drug_code VARCHAR2(15),\n    sub_quantity_dispensed_val NUMBER(10, 2),\n    clm_days_supply_id NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    paid_amount_nm NUMBER(10, 2),\n    mem_prescriber_id_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'CREATE TABLE rxclaims_thp (\n    phm_rx_claim_id_nm VARCHAR2(35),\n    clm_member_id_id VARCHAR2(50),\n    mem_pharmacy_id_val VARCHAR2(35),\n    phm_fill_date_id DATE,\n    drg_drug_code VARCHAR2(15),\n    rx_quantity_dispensed_nm NUMBER(10, 2),\n    days_supply_nm NUMBER(3),\n    clm_billed_amount_nm NUMBER(10, 2),\n    phm_paid_amount_id NUMBER(10, 2),\n    mem_prescriber_id_val VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_thp',
#    'client_name': 'Tufts Health Plan',
#    'client_abbr': 'THP'}},
#  {'content': 'CREATE TABLE rxclaims_wcg (\n    drg_rx_claim_id VARCHAR2(35),\n    sub_member_id_val VARCHAR2(50),\n    pharmacy_id_val VARCHAR2(35),\n    fill_date_id DATE,\n    phm_drug_code_nm VARCHAR2(15),\n    sub_quantity_dispensed_nm NUMBER(10, 2),\n    rx_days_supply_code NUMBER(3),\n    mem_billed_amount_nm NUMBER(10, 2),\n    clm_paid_amount_val NUMBER(10, 2),\n    sub_prescriber_id_code VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_wcg',
#    'client_name': 'WellCare Health Plans',
#    'client_abbr': 'WCG'}},
#  {'content': 'CREATE TABLE rxclaims_tri (\n    clm_rx_claim_id_nm VARCHAR2(35),\n    mem_member_id_id VARCHAR2(50),\n    mem_pharmacy_id_id VARCHAR2(35),\n    rx_fill_date DATE,\n    sub_drug_code_val VARCHAR2(15),\n    phm_quantity_dispensed NUMBER(10, 2),\n    sub_days_supply_id NUMBER(3),\n    rx_billed_amount_id NUMBER(10, 2),\n    phm_paid_amount_id NUMBER(10, 2),\n    sub_prescriber_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'CREATE TABLE rxclaims_mcr (\n    sub_rx_claim_id_val VARCHAR2(35),\n    member_id_val VARCHAR2(50),\n    pharmacy_id_nm VARCHAR2(35),\n    phm_fill_date_id DATE,\n    phm_drug_code VARCHAR2(15),\n    quantity_dispensed_val NUMBER(10, 2),\n    sub_days_supply_id NUMBER(3),\n    mem_billed_amount_id NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    drg_prescriber_id_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_mcr',
#    'client_name': 'Medicare',
#    'client_abbr': 'MCR'}},
#  {'content': 'CREATE TABLE rxclaims_mcd (\n    drg_rx_claim_id_code VARCHAR2(35),\n    sub_member_id VARCHAR2(50),\n    rx_pharmacy_id_val VARCHAR2(35),\n    sub_fill_date DATE,\n    drg_drug_code VARCHAR2(15),\n    phm_quantity_dispensed_nm NUMBER(10, 2),\n    days_supply_val NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    paid_amount_val NUMBER(10, 2),\n    clm_prescriber_id VARCHAR2(35)\n);',
#   'metadata': {'file_name': 'source_layouts_rxclaims_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'CREATE TABLE standard_eligibility (\n    member_id VARCHAR2(50),\n    first_name VARCHAR2(35),\n    last_name VARCHAR2(60),\n    date_of_birth DATE,\n    gender CHAR(1),\n    address VARCHAR2(100),\n    city VARCHAR2(30),\n    state CHAR(2),\n    zip_code VARCHAR2(9),\n    plan_id VARCHAR2(30),\n    group_number VARCHAR2(50),\n    coverage_start_date DATE,\n    coverage_end_date DATE,\n    coverage_level_code CHAR(3),\n    subscriber_indicator CHAR(1),\n    product_category_code CHAR(2),\n    plan_type CHAR(3),\n    market_category_code VARCHAR2(4)\n);',
#   'metadata': {'file_name': 'standard_layouts_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'standard_eligibility',
#    'client_name': 'Default',
#    'client_abbr': 'default'}},
#  {'content': 'CREATE TABLE standard_claims (\n    claim_id VARCHAR2(35),\n    member_id VARCHAR2(50),\n    service_date DATE,\n    admission_date DATE,\n    discharge_date DATE,\n    procedure_code VARCHAR2(10),\n    diagnosis_code VARCHAR2(10),\n    billed_amount NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    provider_id VARCHAR2(35),\n    claim_status VARCHAR2(20),\n    plan_id VARCHAR2(30),\n    place_of_service CHAR(2),\n    type_of_bill CHAR(3),\n    admission_type CHAR(1),\n    discharge_status CHAR(2)\n);',
#   'metadata': {'file_name': 'standard_layouts_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'standard_claims',
#    'client_name': 'Default',
#    'client_abbr': 'default'}},
#  {'content': 'CREATE TABLE standard_rxclaims (\n    rx_claim_id VARCHAR2(35),\n    member_id VARCHAR2(50),\n    pharmacy_id VARCHAR2(35),\n    fill_date DATE,\n    drug_code VARCHAR2(15),\n    quantity_dispensed NUMBER(10, 2),\n    days_supply NUMBER(3),\n    billed_amount NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    prescriber_id VARCHAR2(35),\n    plan_id VARCHAR2(30)\n);',
#   'metadata': {'file_name': 'standard_layouts_ddl.sql',
#    'file_path': '../data/raw',
#    'table_name': 'standard_rxclaims',
#    'client_name': 'Default',
#    'client_abbr': 'default'}}]

# %%
# Write processed DDLs to processed directory
write_to_file(processed_ddls, os.path.join(target_path, "ddls.json"))
# Out:
# File written successfully to: ../data/processed/ddls.json

# %%
# Prepare Data Dictionaries
processed_dds = []
for dd_file in files["dd"]:
    processed_dds.extend(format_dd(dd_file))
    print(f"Processed File: {dd_file}")
# Out:
# Processed File: mcd_eligibility_mcd_data_dictionary.json
# Processed File: hmi_claims_hmi_data_dictionary.json
# Processed File: upmc_rxclaims_upmc_data_dictionary.json
# Processed File: bcbsa_eligibility_bcbsa_data_dictionary.json
# Processed File: hphc_rxclaims_hphc_data_dictionary.json
# Processed File: aet_claims_aet_data_dictionary.json
# Processed File: uhc_rxclaims_uhc_data_dictionary.json
# Processed File: upmc_claims_upmc_data_dictionary.json
# Processed File: cnc_claims_cnc_data_dictionary.json
# Processed File: uhc_eligibility_uhc_data_dictionary.json
# Processed File: uhc_claims_uhc_data_dictionary.json
# Processed File: hum_eligibility_hum_data_dictionary.json
# Processed File: antm_claims_antm_data_dictionary.json
# Processed File: hmi_rxclaims_hmi_data_dictionary.json
# Processed File: antm_rxclaims_antm_data_dictionary.json
# Processed File: wcg_rxclaims_wcg_data_dictionary.json
# Processed File: kp_claims_kp_data_dictionary.json
# Processed File: ci_claims_ci_data_dictionary.json
# Processed File: claims_standard_claims_data_dictionary.json
# Processed File: upmc_eligibility_upmc_data_dictionary.json
# Processed File: moh_rxclaims_moh_data_dictionary.json
# Processed File: hphc_eligibility_hphc_data_dictionary.json
# Processed File: hmi_eligibility_hmi_data_dictionary.json
# Processed File: hcsc_claims_hcsc_data_dictionary.json
# Processed File: moh_eligibility_moh_data_dictionary.json
# Processed File: hcsc_rxclaims_hcsc_data_dictionary.json
# Processed File: eligibility_standard_eligibility_data_dictionary.json
# Processed File: antm_eligibility_antm_data_dictionary.json
# Processed File: bcbsa_claims_bcbsa_data_dictionary.json
# Processed File: bcbsa_rxclaims_bcbsa_data_dictionary.json
# Processed File: mcr_claims_mcr_data_dictionary.json
# Processed File: moh_claims_moh_data_dictionary.json
# Processed File: cnc_eligibility_cnc_data_dictionary.json
# Processed File: aet_eligibility_aet_data_dictionary.json
# Processed File: rxclaims_standard_rxclaims_data_dictionary.json
# Processed File: ghp_eligibility_ghp_data_dictionary.json
# Processed File: thp_claims_thp_data_dictionary.json
# Processed File: kp_rxclaims_kp_data_dictionary.json
# Processed File: wcg_eligibility_wcg_data_dictionary.json
# Processed File: ibc_claims_ibc_data_dictionary.json
# Processed File: aet_rxclaims_aet_data_dictionary.json
# Processed File: tri_eligibility_tri_data_dictionary.json
# Processed File: mcd_claims_mcd_data_dictionary.json
# Processed File: tri_rxclaims_tri_data_dictionary.json
# Processed File: wcg_claims_wcg_data_dictionary.json
# Processed File: mcr_eligibility_mcr_data_dictionary.json
# Processed File: ghp_claims_ghp_data_dictionary.json
# Processed File: kp_eligibility_kp_data_dictionary.json
# Processed File: hphc_claims_hphc_data_dictionary.json
# Processed File: ci_rxclaims_ci_data_dictionary.json
# Processed File: thp_rxclaims_thp_data_dictionary.json
# Processed File: mcd_rxclaims_mcd_data_dictionary.json
# Processed File: mcr_rxclaims_mcr_data_dictionary.json
# Processed File: hum_rxclaims_hum_data_dictionary.json
# Processed File: hcsc_eligibility_hcsc_data_dictionary.json
# Processed File: thp_eligibility_thp_data_dictionary.json
# Processed File: cnc_rxclaims_cnc_data_dictionary.json
# Processed File: ghp_rxclaims_ghp_data_dictionary.json
# Processed File: ibc_rxclaims_ibc_data_dictionary.json
# Processed File: ibc_eligibility_ibc_data_dictionary.json
# Processed File: tri_claims_tri_data_dictionary.json
# Processed File: hum_claims_hum_data_dictionary.json
# Processed File: ci_eligibility_ci_data_dictionary.json

# %%
processed_dds
# Out:
# [{'content': 'column_name: sub_member_id_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier code for the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: first_name\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: mem_last_name_code\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name code of the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: date_of_birth_nm\ndata_type: date\ncolumn_description: Date of birth of the subscriber member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: sub_gender\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender of the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: address_val\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address of the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': "column_name: city_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City code of the subscriber member's address.",
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': "column_name: state_val\ndata_type: char\ncolumn_size: 2\ncolumn_description: State value of the subscriber member's address.",
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': "column_name: sub_zip_code_id\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code identifier for the subscriber member's address.",
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: sub_plan_id_val\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan ID value for the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: mem_group_number_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number value for the subscriber member.',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: mem_coverage_start_date\ndata_type: date\ncolumn_description: Coverage start date for the subscriber member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: sub_coverage_end_date_code\ndata_type: date\ncolumn_description: Coverage end date code for the subscriber member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'mcd_eligibility_mcd_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_mcd',
#    'client_name': 'Medicaid',
#    'client_abbr': 'MCD'}},
#  {'content': 'column_name: claim_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the claim.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: clm_member_id_nm\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Name identifier for the member associated with the claim.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: sub_service_date_val\ndata_type: date\ncolumn_description: Date of the service provided (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: mem_admission_date_nm\ndata_type: date\ncolumn_description: Admission date of the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: clm_discharge_date_val\ndata_type: date\ncolumn_description: Discharge date of the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: clm_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: sub_diagnosis_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Identifier for the diagnosis code.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: billed_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Total amount billed for the claim.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: sub_paid_amount_code\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: sub_provider_id_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier code for the provider.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: claim_status_val\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Current status of the claim.',
#   'metadata': {'file_name': 'hmi_claims_hmi_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hmi',
#    'client_name': 'Highmark Health',
#    'client_abbr': 'HMI'}},
#  {'content': 'column_name: drg_rx_claim_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the drug prescription claim.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: clm_member_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the claim.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: rx_pharmacy_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the pharmacy where the prescription was filled.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: clm_fill_date_val\ndata_type: date\ncolumn_description: Date when the prescription was filled (YYYY-MM-DD).',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: rx_drug_code_code\ndata_type: varchar\ncolumn_size: 15\ncolumn_description: Code representing the drug prescribed.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: mem_quantity_dispensed\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Quantity of the drug dispensed.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: drg_days_supply_val\ndata_type: number\ncolumn_size: 3\ncolumn_description: Number of days the supply of the drug is expected to last.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: clm_billed_amount_code\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the prescription claim.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: clm_paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the prescription claim.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: phm_prescriber_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescriber of the drug.',
#   'metadata': {'file_name': 'upmc_rxclaims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: sub_member_id_nm\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: first_name_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: last_name_nm\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: date_of_birth_nm\ndata_type: date\ncolumn_description: Date of birth of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: gender\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: address\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: mem_city_id\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City identifier for the member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: state_code\ndata_type: char\ncolumn_size: 2\ncolumn_description: State code of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: zip_code\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code of the subscriber member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: mem_plan_id\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan identifier for the member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': "column_name: group_number_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number code for the member's plan.",
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: mem_coverage_start_date_code\ndata_type: date\ncolumn_description: Coverage start date for the member.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: sub_coverage_end_date\ndata_type: date\ncolumn_description: Coverage end date for the subscriber.',
#   'metadata': {'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_bcbsa',
#    'client_name': 'Blue Cross Blue Shield Association',
#    'client_abbr': 'BCBSA'}},
#  {'content': 'column_name: clm_rx_claim_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescription claim.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: sub_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: drg_pharmacy_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Name or identifier of the pharmacy.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: rx_fill_date_nm\ndata_type: date\ncolumn_description: Date when the prescription was filled (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: drg_drug_code\ndata_type: varchar\ncolumn_size: 15\ncolumn_description: Code representing the drug.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: sub_quantity_dispensed_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Quantity of the drug dispensed.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: clm_days_supply_id\ndata_type: number\ncolumn_size: 3\ncolumn_description: Number of days the supply is intended to last.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: drg_billed_amount_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the drug.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: paid_amount_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the drug.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: mem_prescriber_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the prescriber.',
#   'metadata': {'file_name': 'hphc_rxclaims_hphc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_hphc',
#    'client_name': 'Harvard Pilgrim Health Care',
#    'client_abbr': 'HPHC'}},
#  {'content': 'column_name: clm_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the claim.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: member_id_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier code for the member.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: clm_service_date\ndata_type: date\ncolumn_description: Date of service for the claim (YYYY-MM-DD).',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: mem_admission_date\ndata_type: date\ncolumn_description: Admission date of the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: drg_discharge_date_id\ndata_type: date\ncolumn_description: Discharge date related to the DRG (YYYY-MM-DD).',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: mem_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Procedure code value for the member.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: clm_diagnosis_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Diagnosis code identifier for the claim.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: rx_billed_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Billed amount for the prescription.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: provider_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the provider.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: rx_claim_status_id\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status identifier for the prescription claim.',
#   'metadata': {'file_name': 'aet_claims_aet_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_aet',
#    'client_name': 'Aetna',
#    'client_abbr': 'AET'}},
#  {'content': 'column_name: rx_claim_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescription claim.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: sub_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Identifier value for the subscriber member.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: rx_pharmacy_id_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Code identifying the pharmacy.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: sub_fill_date\ndata_type: date\ncolumn_description: Date when the prescription was filled (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: rx_drug_code_id\ndata_type: varchar\ncolumn_size: 15\ncolumn_description: Identifier code for the drug.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: drg_quantity_dispensed_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Quantity of the drug dispensed.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: rx_days_supply_code\ndata_type: number\ncolumn_size: 3\ncolumn_description: Number of days the supply covers.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: rx_billed_amount_code\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the prescription.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: clm_paid_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: phm_prescriber_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier name for the prescriber.',
#   'metadata': {'file_name': 'uhc_rxclaims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': "column_name: mem_claim_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the member's claim.",
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: phm_member_id_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier code for the member.',
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: phm_service_date_nm\ndata_type: date\ncolumn_description: Date of the service provided to the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: phm_admission_date_val\ndata_type: date\ncolumn_description: Date of admission for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: drg_discharge_date_nm\ndata_type: date\ncolumn_description: Date of discharge for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: mem_procedure_code\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed on the member.',
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: drg_diagnosis_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis for the member.',
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': "column_name: mem_billed_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Total amount billed for the member's claim.",
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': "column_name: rx_paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the prescription related to the member's claim.",
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': "column_name: mem_provider_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the provider associated with the member's claim.",
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': "column_name: drg_claim_status\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status of the member's claim.",
#   'metadata': {'file_name': 'upmc_claims_upmc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_upmc',
#    'client_name': 'UPMC Health Plan',
#    'client_abbr': 'UPMC'}},
#  {'content': 'column_name: sub_claim_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the sub claim.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: rx_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the prescription.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: service_date_nm\ndata_type: date\ncolumn_description: Date when the service was provided (YYYY-MM-DD).',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: clm_admission_date_id\ndata_type: date\ncolumn_description: Date of admission for the claim (YYYY-MM-DD).',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: phm_discharge_date_val\ndata_type: date\ncolumn_description: Date of discharge for the pharmacy claim (YYYY-MM-DD).',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: rx_procedure_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure associated with the prescription.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: rx_diagnosis_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis associated with the prescription.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: sub_billed_amount_id\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the sub claim.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: sub_paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the sub claim.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: phm_provider_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the pharmacy provider.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: claim_status_id\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status of the claim.',
#   'metadata': {'file_name': 'cnc_claims_cnc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_cnc',
#    'client_name': 'Centene Corporation',
#    'client_abbr': 'CNC'}},
#  {'content': 'column_name: sub_member_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the subscriber member.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: first_name_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Encoded first name of the member.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: mem_last_name\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the member.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: sub_date_of_birth_val\ndata_type: date\ncolumn_description: Date of birth of the subscriber member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: mem_gender_val\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender value of the member.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: address_id\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Identifier for the address.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: city_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Code representing the city.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: state_nm\ndata_type: char\ncolumn_size: 2\ncolumn_description: State abbreviation.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: sub_zip_code_id\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code identifier for the subscriber.',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': "column_name: sub_plan_id_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Code for the subscriber's plan ID.",
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': "column_name: mem_group_number_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Code for the member's group number.",
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: coverage_start_date_val\ndata_type: date\ncolumn_description: Coverage start date (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: coverage_end_date_id\ndata_type: date\ncolumn_description: Coverage end date (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_eligibility_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: drg_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the DRG claim.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: mem_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: sub_service_date_code\ndata_type: date\ncolumn_description: Date code for the service provided (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: phm_admission_date_nm\ndata_type: date\ncolumn_description: Admission date for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: mem_discharge_date_val\ndata_type: date\ncolumn_description: Discharge date for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: mem_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: diagnosis_code\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: clm_billed_amount_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the claim.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: drg_paid_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the DRG claim.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: sub_provider_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the service provider.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: phm_claim_status_code\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Code representing the status of the claim.',
#   'metadata': {'file_name': 'uhc_claims_uhc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_uhc',
#    'client_name': 'United Healthcare',
#    'client_abbr': 'UHC'}},
#  {'content': 'column_name: mem_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: first_name_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: mem_last_name_val\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: date_of_birth\ndata_type: date\ncolumn_description: Date of birth of the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: gender_code\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender code of the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: sub_address_nm\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address name of the subscriber.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: sub_city_nm\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City name of the subscriber.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: sub_state\ndata_type: char\ncolumn_size: 2\ncolumn_description: State code of the subscriber.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: mem_zip_code\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code of the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: plan_id\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan identifier for the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': "column_name: group_number\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number associated with the member's plan.",
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: mem_coverage_start_date_val\ndata_type: date\ncolumn_description: Coverage start date for the member.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: sub_coverage_end_date_id\ndata_type: date\ncolumn_description: Coverage end date for the subscriber.',
#   'metadata': {'file_name': 'hum_eligibility_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: rx_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescription claim.',
#   'metadata': {'file_name': 'antm_claims_antm_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_antm',
#    'client_name': 'Elevance Health',
#    'client_abbr': 'ANTM'}},
#  {'content': 'column_name: clm_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the claim.',
#   'metadata': {'file_name': 'antm_claims_antm_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_antm',
#    'client_name': 'Elevance Health',
#    'client_abbr': 'ANTM'}},
#  {'content': 'column_name: mem_service_date\ndata_type: date\ncolumn_description: Date of service for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'antm_claims_antm_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_antm',
#    'client_name': 'Elevance Health',
#    'client_abbr': 'ANTM'}},
#  {'content': 'column_name: phm_admission_date_code\ndata_type: date\ncolumn_description: Admission date for pharmacy services (YYYY-MM-DD).',
#   'metadata': {'file_name': 'antm_claims_antm_data_dictionary.json',
# ...
#    'file_path': '../data/raw',
#    'table_name': 'rxclaims_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: sub_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the sub-member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: first_name_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: last_name\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: date_of_birth\ndata_type: date\ncolumn_description: Date of birth of the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: sub_gender_nm\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender of the member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: address_val\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address of the member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': "column_name: city_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City code of the member's address.",
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': "column_name: state_val\ndata_type: char\ncolumn_size: 2\ncolumn_description: State code of the member's address.",
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': "column_name: zip_code_id\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code of the member's address.",
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: mem_plan_id_val\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan ID associated with the member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: mem_group_number\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number associated with the member.',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: mem_coverage_start_date_nm\ndata_type: date\ncolumn_description: Coverage start date for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: mem_coverage_end_date_code\ndata_type: date\ncolumn_description: Coverage end date for the member (YYYY-MM-DD).',
#   'metadata': {'file_name': 'ibc_eligibility_ibc_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ibc',
#    'client_name': 'Independence Blue Cross',
#    'client_abbr': 'IBC'}},
#  {'content': 'column_name: clm_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the claim.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: drg_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the claim.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: phm_service_date_val\ndata_type: date\ncolumn_description: Date when the service was provided (YYYY-MM-DD).',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: admission_date_code\ndata_type: date\ncolumn_description: Date of admission (YYYY-MM-DD).',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: clm_discharge_date\ndata_type: date\ncolumn_description: Date of discharge (YYYY-MM-DD).',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: rx_procedure_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code for the procedure performed.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: mem_diagnosis_code_code\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code for the diagnosis.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: billed_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Total amount billed for the claim.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: mem_paid_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: mem_provider_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the provider.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': 'column_name: sub_claim_status_code\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status code of the claim.',
#   'metadata': {'file_name': 'tri_claims_tri_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_tri',
#    'client_name': 'Tricare',
#    'client_abbr': 'TRI'}},
#  {'content': "column_name: mem_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the member's claim.",
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: rx_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member in the prescription system.',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: rx_service_date\ndata_type: date\ncolumn_description: Date of the service provided (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: phm_admission_date\ndata_type: date\ncolumn_description: Date of admission to the healthcare facility (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: discharge_date_val\ndata_type: date\ncolumn_description: Date of discharge from the healthcare facility (YYYY-MM-DD).',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: phm_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed.',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: phm_diagnosis_code\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis.',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: drg_billed_amount_id\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Billed amount for the DRG (Diagnosis-Related Group).',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: paid_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: rx_provider_id_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier code for the provider in the prescription system.',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: clm_claim_status\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status of the claim.',
#   'metadata': {'file_name': 'hum_claims_hum_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'claims_hum',
#    'client_name': 'Humana',
#    'client_abbr': 'HUM'}},
#  {'content': 'column_name: member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: mem_first_name_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: last_name_code\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: date_of_birth\ndata_type: date\ncolumn_description: Date of birth of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: gender_id\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender identifier of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: address\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: city_val\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: state_val\ndata_type: char\ncolumn_size: 2\ncolumn_description: State of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: mem_zip_code_code\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code of the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: plan_id_val\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan identifier for the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': "column_name: mem_group_number\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number for the member's plan.",
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: mem_coverage_start_date_val\ndata_type: date\ncolumn_description: Coverage start date for the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}},
#  {'content': 'column_name: coverage_end_date_nm\ndata_type: date\ncolumn_description: Coverage end date for the member.',
#   'metadata': {'file_name': 'ci_eligibility_ci_data_dictionary.json',
#    'file_path': '../data/raw',
#    'table_name': 'eligibility_ci',
#    'client_name': 'Cigna Healthcare',
#    'client_abbr': 'CI'}}]

# %%
# Write processed Data Dictionaries to processed directory
write_to_file(processed_dds, os.path.join(target_path, "dds.json"))
# Out:
# File written successfully to: ../data/processed/dds.json
