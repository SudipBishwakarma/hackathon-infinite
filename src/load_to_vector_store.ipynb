# %%
import os, json, sys
from dotenv import load_dotenv
from uuid import uuid4

from pinecone import Pinecone, ServerlessSpec

from langchain_openai import AzureOpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain_core.documents import Document

# %%
load_dotenv()
# Out:
# True

# %%
embed_model = AzureOpenAIEmbeddings(
    azure_endpoint=os.getenv("AZURE_OPENAI_EMBEDDING_ENDPOINT"),
    openai_api_key=os.getenv("AZURE_OPENAI_EMBEDDING_API_KEY"),
    openai_api_version=os.getenv("AZURE_OPENAI_EMBEDDING_API_VERSION"),
    azure_deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME")
)

# %%
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

# %%
index_name = os.getenv("PINECONE_INDEX_NAME")

# %%
if not pc.has_index(index_name):
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1"),
    )

# %%
index = pc.Index(index_name)

# %%
# Delete all records in vector store
index.delete(delete_all=True)
# Out:
# {}

# %%
vector_store = PineconeVectorStore(index=index, embedding=embed_model)

# %%
source_path = "../data/processed"

# %%
# Get list of relevant files for vector store
files = []
for file in os.listdir(source_path):
    if file.endswith(".json"):
        files.append(file)

# %%
files
# Out:
# ['dds.json', 'ddls.json']

# %%
def convert_to_documents(file_name: str) -> list[Document]:
    """Convert contents of file to Langchain Documents."""
    with open(os.path.join(source_path, file_name), "r") as f:
        content = json.loads(f.read())
    docs = [Document(page_content=item["content"], metadata=item["metadata"]) for item in content]
    return docs

# %%
# Prepare Documents
documents = []
for processed_file in files:
    documents.extend(convert_to_documents(processed_file))
    print(f"Processed File: {processed_file}")
# Out:
# Processed File: dds.json
# Processed File: ddls.json

# %%
documents
# Out:
# [Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: sub_member_id_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier code for the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: first_name\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: mem_last_name_code\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name code of the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: date_of_birth_nm\ndata_type: date\ncolumn_description: Date of birth of the subscriber member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: sub_gender\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender of the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: address_val\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address of the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content="column_name: city_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City code of the subscriber member's address."),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content="column_name: state_val\ndata_type: char\ncolumn_size: 2\ncolumn_description: State value of the subscriber member's address."),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content="column_name: sub_zip_code_id\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code identifier for the subscriber member's address."),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: sub_plan_id_val\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan ID value for the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: mem_group_number_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number value for the subscriber member.'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: mem_coverage_start_date\ndata_type: date\ncolumn_description: Coverage start date for the subscriber member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'mcd_eligibility_mcd_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='column_name: sub_coverage_end_date_code\ndata_type: date\ncolumn_description: Coverage end date code for the subscriber member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: claim_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the claim.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: clm_member_id_nm\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Name identifier for the member associated with the claim.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: sub_service_date_val\ndata_type: date\ncolumn_description: Date of the service provided (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: mem_admission_date_nm\ndata_type: date\ncolumn_description: Admission date of the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: clm_discharge_date_val\ndata_type: date\ncolumn_description: Discharge date of the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: clm_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: sub_diagnosis_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Identifier for the diagnosis code.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: billed_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Total amount billed for the claim.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: sub_paid_amount_code\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: sub_provider_id_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier code for the provider.'),
#  Document(metadata={'file_name': 'hmi_claims_hmi_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='column_name: claim_status_val\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Current status of the claim.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: drg_rx_claim_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the drug prescription claim.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: clm_member_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the claim.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: rx_pharmacy_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the pharmacy where the prescription was filled.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: clm_fill_date_val\ndata_type: date\ncolumn_description: Date when the prescription was filled (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: rx_drug_code_code\ndata_type: varchar\ncolumn_size: 15\ncolumn_description: Code representing the drug prescribed.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: mem_quantity_dispensed\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Quantity of the drug dispensed.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: drg_days_supply_val\ndata_type: number\ncolumn_size: 3\ncolumn_description: Number of days the supply of the drug is expected to last.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: clm_billed_amount_code\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the prescription claim.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: clm_paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the prescription claim.'),
#  Document(metadata={'file_name': 'upmc_rxclaims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: phm_prescriber_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescriber of the drug.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: sub_member_id_nm\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: first_name_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: last_name_nm\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: date_of_birth_nm\ndata_type: date\ncolumn_description: Date of birth of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: gender\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: address\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: mem_city_id\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City identifier for the member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: state_code\ndata_type: char\ncolumn_size: 2\ncolumn_description: State code of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: zip_code\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code of the subscriber member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: mem_plan_id\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan identifier for the member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content="column_name: group_number_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number code for the member's plan."),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: mem_coverage_start_date_code\ndata_type: date\ncolumn_description: Coverage start date for the member.'),
#  Document(metadata={'file_name': 'bcbsa_eligibility_bcbsa_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='column_name: sub_coverage_end_date\ndata_type: date\ncolumn_description: Coverage end date for the subscriber.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: clm_rx_claim_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescription claim.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: sub_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: drg_pharmacy_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Name or identifier of the pharmacy.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: rx_fill_date_nm\ndata_type: date\ncolumn_description: Date when the prescription was filled (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: drg_drug_code\ndata_type: varchar\ncolumn_size: 15\ncolumn_description: Code representing the drug.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: sub_quantity_dispensed_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Quantity of the drug dispensed.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: clm_days_supply_id\ndata_type: number\ncolumn_size: 3\ncolumn_description: Number of days the supply is intended to last.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: drg_billed_amount_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the drug.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: paid_amount_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the drug.'),
#  Document(metadata={'file_name': 'hphc_rxclaims_hphc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='column_name: mem_prescriber_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the prescriber.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: clm_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the claim.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: member_id_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier code for the member.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: clm_service_date\ndata_type: date\ncolumn_description: Date of service for the claim (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: mem_admission_date\ndata_type: date\ncolumn_description: Admission date of the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: drg_discharge_date_id\ndata_type: date\ncolumn_description: Discharge date related to the DRG (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: mem_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Procedure code value for the member.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: clm_diagnosis_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Diagnosis code identifier for the claim.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: rx_billed_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Billed amount for the prescription.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: provider_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the provider.'),
#  Document(metadata={'file_name': 'aet_claims_aet_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='column_name: rx_claim_status_id\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status identifier for the prescription claim.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: rx_claim_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescription claim.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Identifier value for the subscriber member.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: rx_pharmacy_id_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Code identifying the pharmacy.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_fill_date\ndata_type: date\ncolumn_description: Date when the prescription was filled (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: rx_drug_code_id\ndata_type: varchar\ncolumn_size: 15\ncolumn_description: Identifier code for the drug.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: drg_quantity_dispensed_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Quantity of the drug dispensed.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: rx_days_supply_code\ndata_type: number\ncolumn_size: 3\ncolumn_description: Number of days the supply covers.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: rx_billed_amount_code\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the prescription.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: clm_paid_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the claim.'),
#  Document(metadata={'file_name': 'uhc_rxclaims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: phm_prescriber_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier name for the prescriber.'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content="column_name: mem_claim_id_nm\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the member's claim."),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: phm_member_id_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier code for the member.'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: phm_service_date_nm\ndata_type: date\ncolumn_description: Date of the service provided to the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: phm_admission_date_val\ndata_type: date\ncolumn_description: Date of admission for the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: drg_discharge_date_nm\ndata_type: date\ncolumn_description: Date of discharge for the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: mem_procedure_code\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed on the member.'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='column_name: drg_diagnosis_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis for the member.'),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content="column_name: mem_billed_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Total amount billed for the member's claim."),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content="column_name: rx_paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the prescription related to the member's claim."),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content="column_name: mem_provider_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the provider associated with the member's claim."),
#  Document(metadata={'file_name': 'upmc_claims_upmc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content="column_name: drg_claim_status\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status of the member's claim."),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: sub_claim_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the sub claim.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: rx_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the prescription.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: service_date_nm\ndata_type: date\ncolumn_description: Date when the service was provided (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: clm_admission_date_id\ndata_type: date\ncolumn_description: Date of admission for the claim (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: phm_discharge_date_val\ndata_type: date\ncolumn_description: Date of discharge for the pharmacy claim (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: rx_procedure_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure associated with the prescription.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: rx_diagnosis_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis associated with the prescription.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: sub_billed_amount_id\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the sub claim.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: sub_paid_amount_val\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the sub claim.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: phm_provider_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the pharmacy provider.'),
#  Document(metadata={'file_name': 'cnc_claims_cnc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='column_name: claim_status_id\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Status of the claim.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_member_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the subscriber member.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: first_name_code\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Encoded first name of the member.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: mem_last_name\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the member.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_date_of_birth_val\ndata_type: date\ncolumn_description: Date of birth of the subscriber member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: mem_gender_val\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender value of the member.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: address_id\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Identifier for the address.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: city_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Code representing the city.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: state_nm\ndata_type: char\ncolumn_size: 2\ncolumn_description: State abbreviation.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_zip_code_id\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code identifier for the subscriber.'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content="column_name: sub_plan_id_code\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Code for the subscriber's plan ID."),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content="column_name: mem_group_number_code\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Code for the member's group number."),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: coverage_start_date_val\ndata_type: date\ncolumn_description: Coverage start date (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_eligibility_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: coverage_end_date_id\ndata_type: date\ncolumn_description: Coverage end date (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: drg_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the DRG claim.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: mem_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_service_date_code\ndata_type: date\ncolumn_description: Date code for the service provided (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: phm_admission_date_nm\ndata_type: date\ncolumn_description: Admission date for the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: mem_discharge_date_val\ndata_type: date\ncolumn_description: Discharge date for the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: mem_procedure_code_val\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: diagnosis_code\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the diagnosis.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: clm_billed_amount_nm\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount billed for the claim.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: drg_paid_amount\ndata_type: number\ncolumn_size: 10, 2\ncolumn_description: Amount paid for the DRG claim.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: sub_provider_id_val\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Identifier for the service provider.'),
#  Document(metadata={'file_name': 'uhc_claims_uhc_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='column_name: phm_claim_status_code\ndata_type: varchar\ncolumn_size: 20\ncolumn_description: Code representing the status of the claim.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: mem_member_id_id\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: first_name_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: First name of the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: mem_last_name_val\ndata_type: varchar\ncolumn_size: 60\ncolumn_description: Last name of the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: date_of_birth\ndata_type: date\ncolumn_description: Date of birth of the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: gender_code\ndata_type: char\ncolumn_size: 1\ncolumn_description: Gender code of the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: sub_address_nm\ndata_type: varchar\ncolumn_size: 100\ncolumn_description: Address name of the subscriber.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: sub_city_nm\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: City name of the subscriber.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: sub_state\ndata_type: char\ncolumn_size: 2\ncolumn_description: State code of the subscriber.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: mem_zip_code\ndata_type: varchar\ncolumn_size: 9\ncolumn_description: ZIP code of the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: plan_id\ndata_type: varchar\ncolumn_size: 30\ncolumn_description: Plan identifier for the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content="column_name: group_number\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Group number associated with the member's plan."),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: mem_coverage_start_date_val\ndata_type: date\ncolumn_description: Coverage start date for the member.'),
#  Document(metadata={'file_name': 'hum_eligibility_hum_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'eligibility_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='column_name: sub_coverage_end_date_id\ndata_type: date\ncolumn_description: Coverage end date for the subscriber.'),
#  Document(metadata={'file_name': 'antm_claims_antm_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='column_name: rx_claim_id_id\ndata_type: varchar\ncolumn_size: 35\ncolumn_description: Unique identifier for the prescription claim.'),
#  Document(metadata={'file_name': 'antm_claims_antm_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='column_name: clm_member_id_val\ndata_type: varchar\ncolumn_size: 50\ncolumn_description: Unique identifier for the member associated with the claim.'),
#  Document(metadata={'file_name': 'antm_claims_antm_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='column_name: mem_service_date\ndata_type: date\ncolumn_description: Date of service for the member (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'antm_claims_antm_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='column_name: phm_admission_date_code\ndata_type: date\ncolumn_description: Admission date for pharmacy services (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'antm_claims_antm_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='column_name: drg_discharge_date_val\ndata_type: date\ncolumn_description: Discharge date for the diagnosis-related group (YYYY-MM-DD).'),
#  Document(metadata={'file_name': 'antm_claims_antm_data_dictionary.json', 'file_path': '../data/raw', 'table_name': 'claims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='column_name: procedure_code_id\ndata_type: varchar\ncolumn_size: 10\ncolumn_description: Code representing the procedure performed.'),
# ...
#  Document(metadata={'file_name': 'source_layouts_claims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'claims_tri', 'client_name': 'Tricare', 'client_abbr': 'TRI'}, page_content='CREATE TABLE claims_tri (\n    clm_claim_id_id VARCHAR2(35),\n    drg_member_id_val VARCHAR2(50),\n    phm_service_date_val DATE,\n    admission_date_code DATE,\n    clm_discharge_date DATE,\n    rx_procedure_code_id VARCHAR2(10),\n    mem_diagnosis_code_code VARCHAR2(10),\n    billed_amount NUMBER(10, 2),\n    mem_paid_amount NUMBER(10, 2),\n    mem_provider_id VARCHAR2(35),\n    sub_claim_status_code VARCHAR2(20)\n);'),
#  Document(metadata={'file_name': 'source_layouts_claims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'claims_mcr', 'client_name': 'Medicare', 'client_abbr': 'MCR'}, page_content='CREATE TABLE claims_mcr (\n    phm_claim_id_code VARCHAR2(35),\n    rx_member_id_nm VARCHAR2(50),\n    drg_service_date_val DATE,\n    sub_admission_date DATE,\n    rx_discharge_date_nm DATE,\n    clm_procedure_code_nm VARCHAR2(10),\n    rx_diagnosis_code_nm VARCHAR2(10),\n    sub_billed_amount_id NUMBER(10, 2),\n    sub_paid_amount_id NUMBER(10, 2),\n    sub_provider_id VARCHAR2(35),\n    rx_claim_status_val VARCHAR2(20)\n);'),
#  Document(metadata={'file_name': 'source_layouts_claims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'claims_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='CREATE TABLE claims_mcd (\n    sub_claim_id_nm VARCHAR2(35),\n    sub_member_id_code VARCHAR2(50),\n    phm_service_date_nm DATE,\n    sub_admission_date_val DATE,\n    phm_discharge_date_id DATE,\n    procedure_code_id VARCHAR2(10),\n    rx_diagnosis_code_code VARCHAR2(10),\n    rx_billed_amount NUMBER(10, 2),\n    mem_paid_amount_code NUMBER(10, 2),\n    mem_provider_id VARCHAR2(35),\n    clm_claim_status VARCHAR2(20)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_uhc', 'client_name': 'United Healthcare', 'client_abbr': 'UHC'}, page_content='CREATE TABLE rxclaims_uhc (\n    rx_claim_id VARCHAR2(35),\n    sub_member_id_val VARCHAR2(50),\n    rx_pharmacy_id_code VARCHAR2(35),\n    sub_fill_date DATE,\n    rx_drug_code_id VARCHAR2(15),\n    drg_quantity_dispensed_nm NUMBER(10, 2),\n    rx_days_supply_code NUMBER(3),\n    rx_billed_amount_code NUMBER(10, 2),\n    clm_paid_amount NUMBER(10, 2),\n    phm_prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_antm', 'client_name': 'Elevance Health', 'client_abbr': 'ANTM'}, page_content='CREATE TABLE rxclaims_antm (\n    sub_rx_claim_id VARCHAR2(35),\n    mem_member_id_id VARCHAR2(50),\n    pharmacy_id_val VARCHAR2(35),\n    clm_fill_date_val DATE,\n    clm_drug_code_code VARCHAR2(15),\n    sub_quantity_dispensed_id NUMBER(10, 2),\n    clm_days_supply NUMBER(3),\n    drg_billed_amount NUMBER(10, 2),\n    phm_paid_amount_code NUMBER(10, 2),\n    sub_prescriber_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_aet', 'client_name': 'Aetna', 'client_abbr': 'AET'}, page_content='CREATE TABLE rxclaims_aet (\n    rx_rx_claim_id_code VARCHAR2(35),\n    phm_member_id VARCHAR2(50),\n    clm_pharmacy_id_nm VARCHAR2(35),\n    rx_fill_date_id DATE,\n    drug_code VARCHAR2(15),\n    mem_quantity_dispensed_id NUMBER(10, 2),\n    mem_days_supply NUMBER(3),\n    phm_billed_amount_id NUMBER(10, 2),\n    clm_paid_amount_code NUMBER(10, 2),\n    drg_prescriber_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_ci', 'client_name': 'Cigna Healthcare', 'client_abbr': 'CI'}, page_content='CREATE TABLE rxclaims_ci (\n    rx_claim_id_nm VARCHAR2(35),\n    phm_member_id_val VARCHAR2(50),\n    sub_pharmacy_id_code VARCHAR2(35),\n    mem_fill_date_val DATE,\n    phm_drug_code VARCHAR2(15),\n    mem_quantity_dispensed_id NUMBER(10, 2),\n    clm_days_supply_id NUMBER(3),\n    rx_billed_amount_nm NUMBER(10, 2),\n    mem_paid_amount_code NUMBER(10, 2),\n    mem_prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_hum', 'client_name': 'Humana', 'client_abbr': 'HUM'}, page_content='CREATE TABLE rxclaims_hum (\n    sub_rx_claim_id_code VARCHAR2(35),\n    rx_member_id VARCHAR2(50),\n    drg_pharmacy_id_code VARCHAR2(35),\n    phm_fill_date_nm DATE,\n    sub_drug_code_nm VARCHAR2(15),\n    rx_quantity_dispensed_nm NUMBER(10, 2),\n    mem_days_supply_val NUMBER(3),\n    billed_amount_id NUMBER(10, 2),\n    phm_paid_amount_nm NUMBER(10, 2),\n    prescriber_id_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_kp', 'client_name': 'Kaiser Permanente', 'client_abbr': 'KP'}, page_content='CREATE TABLE rxclaims_kp (\n    sub_rx_claim_id_code VARCHAR2(35),\n    mem_member_id_nm VARCHAR2(50),\n    clm_pharmacy_id_nm VARCHAR2(35),\n    rx_fill_date_val DATE,\n    drg_drug_code_code VARCHAR2(15),\n    phm_quantity_dispensed NUMBER(10, 2),\n    mem_days_supply_code NUMBER(3),\n    mem_billed_amount_val NUMBER(10, 2),\n    mem_paid_amount_val NUMBER(10, 2),\n    prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_cnc', 'client_name': 'Centene Corporation', 'client_abbr': 'CNC'}, page_content='CREATE TABLE rxclaims_cnc (\n    rx_rx_claim_id_nm VARCHAR2(35),\n    rx_member_id_id VARCHAR2(50),\n    phm_pharmacy_id_id VARCHAR2(35),\n    drg_fill_date_id DATE,\n    drg_drug_code VARCHAR2(15),\n    sub_quantity_dispensed NUMBER(10, 2),\n    mem_days_supply_id NUMBER(3),\n    mem_billed_amount_code NUMBER(10, 2),\n    sub_paid_amount_id NUMBER(10, 2),\n    rx_prescriber_id_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_moh', 'client_name': 'Molina Healthcare', 'client_abbr': 'MOH'}, page_content='CREATE TABLE rxclaims_moh (\n    mem_rx_claim_id_val VARCHAR2(35),\n    clm_member_id_code VARCHAR2(50),\n    clm_pharmacy_id_id VARCHAR2(35),\n    rx_fill_date_val DATE,\n    drg_drug_code VARCHAR2(15),\n    mem_quantity_dispensed_code NUMBER(10, 2),\n    drg_days_supply NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    sub_paid_amount_nm NUMBER(10, 2),\n    rx_prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_bcbsa', 'client_name': 'Blue Cross Blue Shield Association', 'client_abbr': 'BCBSA'}, page_content='CREATE TABLE rxclaims_bcbsa (\n    rx_claim_id_id VARCHAR2(35),\n    sub_member_id VARCHAR2(50),\n    clm_pharmacy_id VARCHAR2(35),\n    fill_date_val DATE,\n    drg_drug_code_val VARCHAR2(15),\n    rx_quantity_dispensed_val NUMBER(10, 2),\n    mem_days_supply_code NUMBER(3),\n    billed_amount_nm NUMBER(10, 2),\n    rx_paid_amount_val NUMBER(10, 2),\n    drg_prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_hcsc', 'client_name': 'Health Care Service Corporation', 'client_abbr': 'HCSC'}, page_content='CREATE TABLE rxclaims_hcsc (\n    drg_rx_claim_id_id VARCHAR2(35),\n    member_id_code VARCHAR2(50),\n    phm_pharmacy_id VARCHAR2(35),\n    sub_fill_date_nm DATE,\n    mem_drug_code_nm VARCHAR2(15),\n    rx_quantity_dispensed_nm NUMBER(10, 2),\n    drg_days_supply_id NUMBER(3),\n    mem_billed_amount_id NUMBER(10, 2),\n    paid_amount_val NUMBER(10, 2),\n    mem_prescriber_id_val VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_hmi', 'client_name': 'Highmark Health', 'client_abbr': 'HMI'}, page_content='CREATE TABLE rxclaims_hmi (\n    sub_rx_claim_id_nm VARCHAR2(35),\n    member_id_nm VARCHAR2(50),\n    drg_pharmacy_id_code VARCHAR2(35),\n    drg_fill_date_id DATE,\n    drug_code_code VARCHAR2(15),\n    sub_quantity_dispensed_val NUMBER(10, 2),\n    sub_days_supply NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    rx_prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_ghp', 'client_name': 'Geisinger Health Plan', 'client_abbr': 'GHP'}, page_content='CREATE TABLE rxclaims_ghp (\n    clm_rx_claim_id_val VARCHAR2(35),\n    phm_member_id_id VARCHAR2(50),\n    sub_pharmacy_id VARCHAR2(35),\n    drg_fill_date DATE,\n    sub_drug_code_id VARCHAR2(15),\n    phm_quantity_dispensed_nm NUMBER(10, 2),\n    rx_days_supply NUMBER(3),\n    drg_billed_amount_code NUMBER(10, 2),\n    sub_paid_amount_nm NUMBER(10, 2),\n    drg_prescriber_id_nm VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_upmc', 'client_name': 'UPMC Health Plan', 'client_abbr': 'UPMC'}, page_content='CREATE TABLE rxclaims_upmc (\n    drg_rx_claim_id_nm VARCHAR2(35),\n    clm_member_id VARCHAR2(50),\n    rx_pharmacy_id_id VARCHAR2(35),\n    clm_fill_date_val DATE,\n    rx_drug_code_code VARCHAR2(15),\n    mem_quantity_dispensed NUMBER(10, 2),\n    drg_days_supply_val NUMBER(3),\n    clm_billed_amount_code NUMBER(10, 2),\n    clm_paid_amount_val NUMBER(10, 2),\n    phm_prescriber_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_ibc', 'client_name': 'Independence Blue Cross', 'client_abbr': 'IBC'}, page_content='CREATE TABLE rxclaims_ibc (\n    drg_rx_claim_id_nm VARCHAR2(35),\n    phm_member_id_code VARCHAR2(50),\n    sub_pharmacy_id_nm VARCHAR2(35),\n    mem_fill_date_id DATE,\n    phm_drug_code_code VARCHAR2(15),\n    mem_quantity_dispensed_code NUMBER(10, 2),\n    drg_days_supply_id NUMBER(3),\n    billed_amount_id NUMBER(10, 2),\n    mem_paid_amount_nm NUMBER(10, 2),\n    rx_prescriber_id_code VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_hphc', 'client_name': 'Harvard Pilgrim Health Care', 'client_abbr': 'HPHC'}, page_content='CREATE TABLE rxclaims_hphc (\n    clm_rx_claim_id_val VARCHAR2(35),\n    sub_member_id_val VARCHAR2(50),\n    drg_pharmacy_id_nm VARCHAR2(35),\n    rx_fill_date_nm DATE,\n    drg_drug_code VARCHAR2(15),\n    sub_quantity_dispensed_val NUMBER(10, 2),\n    clm_days_supply_id NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    paid_amount_nm NUMBER(10, 2),\n    mem_prescriber_id_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_thp', 'client_name': 'Tufts Health Plan', 'client_abbr': 'THP'}, page_content='CREATE TABLE rxclaims_thp (\n    phm_rx_claim_id_nm VARCHAR2(35),\n    clm_member_id_id VARCHAR2(50),\n    mem_pharmacy_id_val VARCHAR2(35),\n    phm_fill_date_id DATE,\n    drg_drug_code VARCHAR2(15),\n    rx_quantity_dispensed_nm NUMBER(10, 2),\n    days_supply_nm NUMBER(3),\n    clm_billed_amount_nm NUMBER(10, 2),\n    phm_paid_amount_id NUMBER(10, 2),\n    mem_prescriber_id_val VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_wcg', 'client_name': 'WellCare Health Plans', 'client_abbr': 'WCG'}, page_content='CREATE TABLE rxclaims_wcg (\n    drg_rx_claim_id VARCHAR2(35),\n    sub_member_id_val VARCHAR2(50),\n    pharmacy_id_val VARCHAR2(35),\n    fill_date_id DATE,\n    phm_drug_code_nm VARCHAR2(15),\n    sub_quantity_dispensed_nm NUMBER(10, 2),\n    rx_days_supply_code NUMBER(3),\n    mem_billed_amount_nm NUMBER(10, 2),\n    clm_paid_amount_val NUMBER(10, 2),\n    sub_prescriber_id_code VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_tri', 'client_name': 'Tricare', 'client_abbr': 'TRI'}, page_content='CREATE TABLE rxclaims_tri (\n    clm_rx_claim_id_nm VARCHAR2(35),\n    mem_member_id_id VARCHAR2(50),\n    mem_pharmacy_id_id VARCHAR2(35),\n    rx_fill_date DATE,\n    sub_drug_code_val VARCHAR2(15),\n    phm_quantity_dispensed NUMBER(10, 2),\n    sub_days_supply_id NUMBER(3),\n    rx_billed_amount_id NUMBER(10, 2),\n    phm_paid_amount_id NUMBER(10, 2),\n    sub_prescriber_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_mcr', 'client_name': 'Medicare', 'client_abbr': 'MCR'}, page_content='CREATE TABLE rxclaims_mcr (\n    sub_rx_claim_id_val VARCHAR2(35),\n    member_id_val VARCHAR2(50),\n    pharmacy_id_nm VARCHAR2(35),\n    phm_fill_date_id DATE,\n    phm_drug_code VARCHAR2(15),\n    quantity_dispensed_val NUMBER(10, 2),\n    sub_days_supply_id NUMBER(3),\n    mem_billed_amount_id NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    drg_prescriber_id_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'source_layouts_rxclaims_ddl.sql', 'file_path': '../data/raw', 'table_name': 'rxclaims_mcd', 'client_name': 'Medicaid', 'client_abbr': 'MCD'}, page_content='CREATE TABLE rxclaims_mcd (\n    drg_rx_claim_id_code VARCHAR2(35),\n    sub_member_id VARCHAR2(50),\n    rx_pharmacy_id_val VARCHAR2(35),\n    sub_fill_date DATE,\n    drg_drug_code VARCHAR2(15),\n    phm_quantity_dispensed_nm NUMBER(10, 2),\n    days_supply_val NUMBER(3),\n    drg_billed_amount_nm NUMBER(10, 2),\n    paid_amount_val NUMBER(10, 2),\n    clm_prescriber_id VARCHAR2(35)\n);'),
#  Document(metadata={'file_name': 'standard_layouts_ddl.sql', 'file_path': '../data/raw', 'table_name': 'standard_eligibility', 'client_name': 'Default', 'client_abbr': 'default'}, page_content='CREATE TABLE standard_eligibility (\n    member_id VARCHAR2(50),\n    first_name VARCHAR2(35),\n    last_name VARCHAR2(60),\n    date_of_birth DATE,\n    gender CHAR(1),\n    address VARCHAR2(100),\n    city VARCHAR2(30),\n    state CHAR(2),\n    zip_code VARCHAR2(9),\n    plan_id VARCHAR2(30),\n    group_number VARCHAR2(50),\n    coverage_start_date DATE,\n    coverage_end_date DATE,\n    coverage_level_code CHAR(3),\n    subscriber_indicator CHAR(1),\n    product_category_code CHAR(2),\n    plan_type CHAR(3),\n    market_category_code VARCHAR2(4)\n);'),
#  Document(metadata={'file_name': 'standard_layouts_ddl.sql', 'file_path': '../data/raw', 'table_name': 'standard_claims', 'client_name': 'Default', 'client_abbr': 'default'}, page_content='CREATE TABLE standard_claims (\n    claim_id VARCHAR2(35),\n    member_id VARCHAR2(50),\n    service_date DATE,\n    admission_date DATE,\n    discharge_date DATE,\n    procedure_code VARCHAR2(10),\n    diagnosis_code VARCHAR2(10),\n    billed_amount NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    provider_id VARCHAR2(35),\n    claim_status VARCHAR2(20),\n    plan_id VARCHAR2(30),\n    place_of_service CHAR(2),\n    type_of_bill CHAR(3),\n    admission_type CHAR(1),\n    discharge_status CHAR(2)\n);'),
#  Document(metadata={'file_name': 'standard_layouts_ddl.sql', 'file_path': '../data/raw', 'table_name': 'standard_rxclaims', 'client_name': 'Default', 'client_abbr': 'default'}, page_content='CREATE TABLE standard_rxclaims (\n    rx_claim_id VARCHAR2(35),\n    member_id VARCHAR2(50),\n    pharmacy_id VARCHAR2(35),\n    fill_date DATE,\n    drug_code VARCHAR2(15),\n    quantity_dispensed NUMBER(10, 2),\n    days_supply NUMBER(3),\n    billed_amount NUMBER(10, 2),\n    paid_amount NUMBER(10, 2),\n    prescriber_id VARCHAR2(35),\n    plan_id VARCHAR2(30)\n);')]

# %%
# Generate unique ids for each document
document_ids = [str(uuid4()) for _ in range(len(documents))]

# %%
document_ids
# Out:
# ['07e197d1-0813-4b39-9fe7-741f96c32510',
#  '3aafee1e-1295-4c00-8b84-e2c332bb0f2c',
#  'd657436a-5b50-49e8-b3e3-1edfb6ca93ef',
#  '4dacecfd-212d-40bd-bf64-3464fdcd8b2e',
#  '7ea1c6c2-91d8-4d38-9cae-b2c6453c8bf1',
#  '630a7fea-21f2-4690-8292-865e1244a2e3',
#  '6d27122c-6926-4474-a6a8-f8b7560ac910',
#  'fd970bd8-97b4-4063-9db0-94808dead003',
#  '9bc3bae8-dda5-43a4-985c-e7e33c3c9c5f',
#  'da508033-6d2d-43ee-88b5-60f1f1a7468b',
#  '0ea1358b-e10b-4d86-b95d-0ee1e7571740',
#  '30e9e578-0ad1-4807-9dbb-3bff9c56cdfb',
#  'ab355b6f-95af-46ed-8f8b-a87d958b0b2d',
#  'b1951675-7900-4034-8500-38166875e00d',
#  '7e1582da-7c94-4d91-866c-5755bd79496c',
#  '2f337006-0567-4291-b4c2-b299e723373d',
#  'c5f25fb7-b7a8-4af5-b413-254112023829',
#  '5e25f77a-17e7-438b-8230-8a8f28cf1e61',
#  'dbd44435-c0eb-4b3a-aa03-1be65c188df1',
#  'aee833eb-2d80-4873-a109-ca6b1d17dd1b',
#  '7c26c58b-f929-44ef-9355-6efdaa417541',
#  '5793c5fb-eb66-42a4-b17f-5809ef586f0a',
#  '76dcf42f-e027-41f9-881f-b688eb9708bc',
#  '8e81da36-c464-41bd-8727-e06c804aefb9',
#  '024088ec-308b-410e-b23c-59a83b5e7285',
#  '77ff4490-d808-4d6b-b4c6-d18ac05f428c',
#  '92a47209-1a20-4456-8492-881425eab2a9',
#  '17827acb-92ca-4ae2-a862-6ad410d4ae70',
#  'e4c48fad-b3ae-4142-856a-1abb46fcd63e',
#  'b4a52e43-a4ed-43f6-b1f3-eee02d2dc2a9',
#  '7e9041b3-0210-46d6-93c1-dba6b85ac625',
#  'f3f34649-b228-4ebb-8a3a-f1e564aecff7',
#  '9dc65c1e-89f8-49cc-8f65-5314466c4e2b',
#  '7d78302f-9cc8-475b-a78c-3f776aabb604',
#  '505e3600-71a6-43ad-9a7c-88a4b11232cc',
#  '36006a3c-6fb6-446c-be90-31e9122dc547',
#  '0bd79d49-c825-4499-b193-fad7598d201d',
#  '5c497427-1440-48c9-997c-492d04394d69',
#  '6c88d9f1-e7f6-476a-95ac-3b3906bf5160',
#  '0fba770d-8c53-4e20-b45b-f6603fdc5b27',
#  '331a3e8c-f4b9-445d-9a33-5be2f26597a4',
#  '91b3f60a-51ce-40f0-a0bc-2f4407f9d452']

# %%
len(document_ids)
# Out:
# 788

# %%
# Publish knowledgebase to vector store
failed = []
for doc, doc_id in zip(documents, document_ids):
    try:
        vector_store.add_documents(documents=[doc], ids=[doc_id])
        print(f"Added: {doc_id}")
    except Exception as ex:
        failed.append([doc, doc_id])
        print(f"Failed to add: {doc_id}")
# Out:
# Added: 07e197d1-0813-4b39-9fe7-741f96c32510
# Added: 3aafee1e-1295-4c00-8b84-e2c332bb0f2c
# Added: d657436a-5b50-49e8-b3e3-1edfb6ca93ef
# Added: 4dacecfd-212d-40bd-bf64-3464fdcd8b2e
# Added: 7ea1c6c2-91d8-4d38-9cae-b2c6453c8bf1
# Added: 630a7fea-21f2-4690-8292-865e1244a2e3
# Added: 6b120dbb-69e3-490c-9e7f-a5c35a1bf6a9
# Added: b6c6c993-28a4-4e6b-be1b-d2b9ebd36117
